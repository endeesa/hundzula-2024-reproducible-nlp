# %% [markdown]
# # Summary
#
# * This notebook primarily focuses on analyzing and classifying news articles as either fake or true. The following major steps and operations are carried out
#
# *  The goal is to analyze and categorize news content, potentially aiding in the identification of misinformation or disinformation.

# %%
# %pip install Pydrive comet-ml --quiet --upgrade
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.6/601.6 kB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 48.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.5/257.5 kB 25.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 514.7/514.7 kB 37.4 MB/s eta 0:00:00

# %%
import os
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Out:
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive

# %%
# Download data from Google Drive
## Alternative: Download the data manually

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

id = "1W7r4syQz5hmIHRIEELutpEj54obWnBPM"
imported = drive.CreateFile({'id': id})
imported.GetContentFile('Fake.csv')


id = "1pKEZvEG_ElUJd2F7sDmqVTy4v0kMb92R"
imported = drive.CreateFile({'id': id})
imported.GetContentFile('True.csv')

# %% [markdown]
# # Data Loading
# 1. The notebook starts by installing the `Pydrive` library, which is used for interfacing with Google Drive.
# 2. It imports necessary libraries such as `GoogleAuth`, `GoogleDrive`, `auth`, and `GoogleCredentials` to authenticate and access Google Drive.
# 3. The notebook authenticates the user and sets up the Google Drive client.
# 4. It then fetches two CSV files, 'Fake.csv' and 'True.csv', from Google Drive and loads them into dataframes `df_fake_news` and `df_true_news` respectively.

# %%
df_true_news = pd.read_csv('True.csv')
df_fake_news = pd.read_csv('Fake.csv')

# %%
df_fake_news.head(20)
# Out:
#                                                 title  \
# 0    Donald Trump Sends Out Embarrassing New Year’...
# 1    Drunk Bragging Trump Staffer Started Russian ...
# 2    Sheriff David Clarke Becomes An Internet Joke...
# 3    Trump Is So Obsessed He Even Has Obama’s Name...
# 4    Pope Francis Just Called Out Donald Trump Dur...
# 5    Racist Alabama Cops Brutalize Black Boy While...
# 6    Fresh Off The Golf Course, Trump Lashes Out A...
# 7    Trump Said Some INSANELY Racist Stuff Inside ...
# 8    Former CIA Director Slams Trump Over UN Bully...
# 9    WATCH: Brand-New Pro-Trump Ad Features So Muc...
# 10   Papa John’s Founder Retires, Figures Out Raci...
# 11   WATCH: Paul Ryan Just Told Us He Doesn’t Care...
# 12   Bad News For Trump — Mitch McConnell Says No ...
# 13   WATCH: Lindsey Graham Trashes Media For Portr...
# 14   Heiress To Disney Empire Knows GOP Scammed Us...
# 15   Tone Deaf Trump: Congrats Rep. Scalise On Los...
# ...

# %%
df_true_news.head(20)
# Out:
#                                                 title  \
# 0   As U.S. budget fight looms, Republicans flip t...
# 1   U.S. military to accept transgender recruits o...
# 2   Senior U.S. Republican senator: 'Let Mr. Muell...
# 3   FBI Russia probe helped by Australian diplomat...
# 4   Trump wants Postal Service to charge 'much mor...
# 5   White House, Congress prepare for talks on spe...
# 6   Trump says Russia probe will be fair, but time...
# 7   Factbox: Trump on Twitter (Dec 29) - Approval ...
# 8          Trump on Twitter (Dec 28) - Global Warming
# 9   Alabama official to certify Senator-elect Jone...
# 10  Jones certified U.S. Senate winner despite Moo...
# 11  New York governor questions the constitutional...
# 12  Factbox: Trump on Twitter (Dec 28) - Vanity Fa...
# 13     Trump on Twitter (Dec 27) - Trump, Iraq, Syria
# 14  Man says he delivered manure to Mnuchin to pro...
# 15  Virginia officials postpone lottery drawing to...
# ...

# %%
df_fake_news.count()
# Out:
# title      23481
# text       23481
# subject    23481
# date       23481
# dtype: int64

# %%
df_true_news.count()
# Out:
# title      21417
# text       21417
# subject    21417
# date       21417
# dtype: int64

# %% [markdown]
# # Data Preprocessing

# %%
#Find Missing Data if any at all
def find_missing_vals(data):
  total = len(data)
  for column in data.columns:
    if data[column].isna().sum() != 0:
      print("{} has: {:,} ({:.2}%) missing values.".format(column, data[column].isna().sum(),
                                                     (data[column].isna().sum()/total)*100))
    else:
      print("{} has no any missing value".format(column))
      print("\nMissing Value Summary\n{}".format("-"*35))
      print("\ndf_db\n{}".format("-"*15))
      print(data.isnull().sum(axis = 0))

# %%
def remove_duplicates(data):
  print("\nCleaning Summary\n{}".format("-"*35))
  size_before = len(data)
  data.drop_duplicates(subset= None, keep="first", inplace=True)
  size_after = len(data)
  print("... removed{} duplicate rows in db data".format(size_before-size_after))

# %%
find_missing_vals(df_fake_news)
# Out:
# title has no any missing value
#
# Missing Value Summary
# -----------------------------------
#
# df_db
# ---------------
# title      0
# text       0
# subject    0
# date       0
# dtype: int64
# text has no any missing value
#
# Missing Value Summary
# -----------------------------------
#
# df_db
# ---------------
# title      0
# text       0
# subject    0
# date       0
# dtype: int64
# subject has no any missing value
#
# Missing Value Summary
# -----------------------------------
#
# df_db
# ---------------
# title      0
# text       0
# subject    0
# date       0
# dtype: int64
# date has no any missing value
#
# Missing Value Summary
# -----------------------------------
#
# df_db
# ---------------
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
find_missing_vals(df_true_news)
# Out:
# title has no any missing value
#
# Missing Value Summary
# -----------------------------------
#
# df_db
# ---------------
# title      0
# text       0
# subject    0
# date       0
# dtype: int64
# text has no any missing value
#
# Missing Value Summary
# -----------------------------------
#
# df_db
# ---------------
# title      0
# text       0
# subject    0
# date       0
# dtype: int64
# subject has no any missing value
#
# Missing Value Summary
# -----------------------------------
#
# df_db
# ---------------
# title      0
# text       0
# subject    0
# date       0
# dtype: int64
# date has no any missing value
#
# Missing Value Summary
# -----------------------------------
#
# df_db
# ---------------
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
remove_duplicates(df_fake_news)
# Out:
# Cleaning Summary
# -----------------------------------
# ... removed3 duplicate rows in db data

# %%
remove_duplicates(df_true_news)
# Out:
# Cleaning Summary
# -----------------------------------
# ... removed206 duplicate rows in db data

# %%
df_merged = pd.merge(df_fake_news, df_true_news, how= 'outer')
df_merged.describe()
# Out:
#                                                     title   text  \
# count                                               44689  44689
# unique                                              38729  38646
# top     Factbox: Trump fills top jobs for his administ...
# freq                                                   14    627
#
#              subject               date
# count          44689              44689
# unique             8               2397
# top     politicsNews  December 6, 2017
# freq           11220                166

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt
#sns.set(style="ticks", color_codes= True)

#fig_dims = (20, 4.8)
#fig, ax = plt.subplots(figsize = fig_dims)
#sns.countplot(df_merged["subject"],ax=ax, data = df_merged);

# %%
df_fake_news['label'] = 0
df_true_news['label'] = 1

# %%
df_train= pd.merge(df_fake_news, df_true_news, how = 'outer')
df_merged.describe()
# Out:
#                                                     title   text  \
# count                                               44689  44689
# unique                                              38729  38646
# top     Factbox: Trump fills top jobs for his administ...
# freq                                                   14    627
#
#              subject               date
# count          44689              44689
# unique             8               2397
# top     politicsNews  December 6, 2017
# freq           11220                166

# %% [markdown]
# # Tokenization

# %%
# !pip install sklearn   # This should be pre-installed on chrome already

# %%
import nltk
import string
from nltk.corpus import stopwords

from sklearn.model_selection import train_test_split

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# Remove stopwords and punctuations

# %%
def text_process(text):
  no_punctuation = [char for char in text if char not in string.punctuation]
  # no_punction = ''.join(no_punctuation)
  return [word.lower() for word in ''.join(no_punctuation).split() if word.lower() not in stopwords.words('english')]

# %%
X_train, X_test, y_train, y_test = train_test_split(df_train['title'] , df_train['label'], test_size=0.2, random_state=42)

# %% [markdown]
# # Model Training

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import Pipeline

# %%
news_classifier = Pipeline ([
    ('vectorizer', CountVectorizer(analyzer=text_process)),
    ('tfidf', TfidfTransformer()),
    ('classifier', MLPClassifier(solver= 'adam', activation= 'tanh',
                                          random_state=1, max_iter=200,
                                          early_stopping=True))
])

# %%
news_classifier.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer',
#                  CountVectorizer(analyzer=<function text_process at 0x7821d0d77c70>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('classifier',
#                  MLPClassifier(activation='tanh', early_stopping=True,
#                                random_state=1))])

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import classification_report

# %%
predicted = news_classifier.predict(X_test)

# %%
print(classification_report(predicted, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      4677
#            1       0.97      0.95      0.96      4261
#
#     accuracy                           0.96      8938
#    macro avg       0.96      0.96      0.96      8938
# weighted avg       0.96      0.96      0.96      8938

# %% [markdown]
# **Log more results to Comet.Ml**

# %%
# log confusion matrix + text
# log interactive html charts

# %% [markdown]
# # (Optional) Hyperparameter Tuning
